# %%
import os
import pandas as pd

# %%
data= pd.read_csv("listings.csv")
data
# Out:
#                        id                                      listing_url  \
# 0                   11532               https://www.airbnb.com/rooms/11532
# 1                   14842               https://www.airbnb.com/rooms/14842
# 2                   36950               https://www.airbnb.com/rooms/36950
# 3                   40176               https://www.airbnb.com/rooms/40176
# 4                   42037               https://www.airbnb.com/rooms/42037
# ...                   ...                                              ...
# 28492  973201249302604095  https://www.airbnb.com/rooms/973201249302604095
# 28493  973204906314719246  https://www.airbnb.com/rooms/973204906314719246
# 28494  973239728151294861  https://www.airbnb.com/rooms/973239728151294861
# 28495  973308231903797874  https://www.airbnb.com/rooms/973308231903797874
# 28496  973881708971535524  https://www.airbnb.com/rooms/973881708971535524
#
#             scrape_id last_searched last_scraped  \
# ...

# %%
data.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_searched', 'last_scraped',
#        'name', 'description', 'neighborhood_overview', 'picture_url',
#        'host_id', 'host_url', 'host_name', 'host_since', 'host_location',
#        'host_about', 'host_response_time', 'host_response_rate',
#        'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url',
#        'host_picture_url', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'latitude', 'longitude', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
data.tail()
# Out:
#                        id                                      listing_url  \
# 28492  973201249302604095  https://www.airbnb.com/rooms/973201249302604095
# 28493  973204906314719246  https://www.airbnb.com/rooms/973204906314719246
# 28494  973239728151294861  https://www.airbnb.com/rooms/973239728151294861
# 28495  973308231903797874  https://www.airbnb.com/rooms/973308231903797874
# 28496  973881708971535524  https://www.airbnb.com/rooms/973881708971535524
#
#             scrape_id last_searched last_scraped  \
# 28492  20230906022940    2023-09-06   2023-09-08
# 28493  20230906022940    2023-09-06   2023-09-08
# 28494  20230906022940    2023-09-06   2023-09-07
# 28495  20230906022940    2023-09-06   2023-09-08
# 28496  20230906022940    2023-09-06   2023-09-08
#
#                                                     name  \
# 28492  Rental unit in Dublin · ★New · 2 bedrooms · 1 ...
# 28493  Home in County Kerry · ★New · 1 bedroom · 2 be...
# ...

# %%
df = pd.DataFrame(data) 
  
display(df.drop_duplicates()) # drop duplicate rows and coloums from the dataset
# Out:
#                        id                                      listing_url  \
# 0                   11532               https://www.airbnb.com/rooms/11532
# 1                   14842               https://www.airbnb.com/rooms/14842
# 2                   36950               https://www.airbnb.com/rooms/36950
# 3                   40176               https://www.airbnb.com/rooms/40176
# 4                   42037               https://www.airbnb.com/rooms/42037
# ...                   ...                                              ...
# 28492  973201249302604095  https://www.airbnb.com/rooms/973201249302604095
# 28493  973204906314719246  https://www.airbnb.com/rooms/973204906314719246
# 28494  973239728151294861  https://www.airbnb.com/rooms/973239728151294861
# 28495  973308231903797874  https://www.airbnb.com/rooms/973308231903797874
# 28496  973881708971535524  https://www.airbnb.com/rooms/973881708971535524
#
#             scrape_id last_searched last_scraped  \
# ...

# %%
df = pd.DataFrame(data, columns= ['price', 'host_location', 'host_since'])
exchange_rate = 0.95  # Replace with the actual exchange rate
# Exchange rate
exchange_rate = 0.95

# Remove commas and dollar signs, convert the "price" column to float, and convert to Euros
df['price'] = df['price'].str.replace(',', '', regex=True).str.replace('$', '').astype(float) * exchange_rate

# Print the DataFrame
print(df)
# Out:
#         price          host_location  host_since
# 0      445.55      Westport, Ireland  2009-10-02
# 1      141.55        Dublin, Ireland  2009-11-29
# 2       85.50  County Clare, Ireland  2010-07-06
# 3      128.25        Galway, Ireland  2010-07-19
# 4       79.80                Ireland  2010-07-27
# ...       ...                    ...         ...
# 28492  162.45                    NaN  2023-01-26
# 28493   82.65                    NaN  2016-07-05
# 28494  171.00                    NaN  2021-10-13
# 28495   95.00        Dublin, Ireland  2018-11-18
# 28496  114.00                    NaN  2023-09-05
#
# [28497 rows x 3 columns]

# %%
df.tail()
# Out:
#        price    host_location  host_since
# 28492  171.0              NaN  2023-01-26
# 28493   87.0              NaN  2016-07-05
# 28494  180.0              NaN  2021-10-13
# 28495  100.0  Dublin, Ireland  2018-11-18
# 28496  120.0              NaN  2023-09-05

# %%
print (df)
# Out:
#         Price          host_location  host_since
# 0      445.55      Westport, Ireland  2009-10-02
# 1      141.55        Dublin, Ireland  2009-11-29
# 2       85.50  County Clare, Ireland  2010-07-06
# 3      128.25        Galway, Ireland  2010-07-19
# 4       79.80                Ireland  2010-07-27
# ...       ...                    ...         ...
# 28492  162.45                    NaN  2023-01-26
# 28493   82.65                    NaN  2016-07-05
# 28494  171.00                    NaN  2021-10-13
# 28495   95.00        Dublin, Ireland  2018-11-18
# 28496  114.00                    NaN  2023-09-05
#
# [28497 rows x 3 columns]

# %%
# Drop the NaN values from the DataFrame
df = df.dropna()

print(df)
# Out:
#          price             host_location  host_since
# 0       445.55         Westport, Ireland  2009-10-02
# 1       141.55           Dublin, Ireland  2009-11-29
# 2        85.50     County Clare, Ireland  2010-07-06
# 3       128.25           Galway, Ireland  2010-07-19
# 4        79.80                   Ireland  2010-07-27
# ...        ...                       ...         ...
# 28487    38.00            Louth, Ireland  2016-06-02
# 28488   196.65           Dublin, Ireland  2023-09-04
# 28489  1064.00  Leitrim Village, Ireland  2023-04-29
# 28491   416.10        Blackrock, Ireland  2017-07-25
# 28495    95.00           Dublin, Ireland  2018-11-18
#
# [20409 rows x 3 columns]

# %%
# Export the DataFrame to a CSV file
df.to_csv('../Charts/new_ListingsData.csv')
